# %%
import requests

# Define essential fields for everyday use, including nutrition-related ones
essential_fields = [
    "_id", "product_name", "brands", "categories", "countries",
    "ingredients_text", "labels", "nutriscore_grade", "nutriscore_score",
    "nova_group", "nutriments.energy_100g", "nutriments.fat_100g",
    "nutriments.saturated-fat_100g", "nutriments.carbohydrates_100g",
    "nutriments.sugars_100g", "nutriments.fiber_100g",
    "nutriments.proteins_100g", "nutriments.salt_100g", "nutriments.sodium_100g"
]

# API URL
api_url = "https://world.openfoodfacts.org/cgi/search.pl"

# %%
# Define parameters to fetch data
params = {
    "action": "process",
    "json": 1,
    "fields": ",".join(essential_fields),  # Fetch only essential fields
    "page_size": 100,  # Number of items per request
    "page": 1          # Start with the first page
}

# Fetch data from the API
response = requests.get(api_url, params=params)

# Check response and extract products
if response.status_code == 200:
    data = response.json()
    products = data.get("products", [])
    print(f"Fetched {len(products)} products.")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Failed to fetch data. Status code: 429

# %%
import random

# Function to inspect all data for 20 randomly sampled products
def inspect_sampled_products_full(products, sample_size=20):
    if not products:
        print("No products available to inspect.")
        return

    # Randomly sample products (ensure we don't sample more than available)
    sample_size = min(sample_size, len(products))
    sampled_products = random.sample(products, sample_size)

    print(f"Displaying all data for {sample_size} randomly sampled products:\n")
    for i, product in enumerate(sampled_products, start=1):
        product_name = product.get("product_name", "Unknown Product")
        print(f"Product {i}: {product_name}")
        print("All Data:")
        for key, value in product.items():
            print(f"  {key}: {value}")
        print("-" * 80)

# Inspect a sample of 20 products
inspect_sampled_products_full(products, sample_size=20)
# Out:
# Displaying all data for 20 randomly sampled products:
#
# Product 1: Biscuit soja orange
# All Data:
#   _id: 3175680011442
#   brands: Gerblé
#   categories: Snacks,Petit-déjeuners,Snacks sucrés,Biscuits et gâteaux,Biscuits sucrés & biscuits apéritifs,Biscuits,Biscuits croustillants,Biscuit sec croquant allégé en matière grasse,Biscuits secs,Biscuits sablés,Biscuit sec pour petit déjeuner,Biscuit sec aux fruits
#   countries: France,Guadeloupe,Martinique,La Réunion
#   ingredients_text: Farine de _blé_ 57,7%, sucre de canne roux, huile de colza, flocons de _soja_ 7%, germe de _blé_ 5,4%, oranges déshydratées 1,5%, magnésium, sucre, amidon de maïs, jus concentré de citron émulsifiant : lécithines de colza, sel de mer, arôme naturel d'orange, calcium, poudres à lever : carbonates de sodium amidon, vitamines (E, PP, B5, B6, B1, B9).
#   labels: Fabriqué en France,Nutriscore,Nutriscore B,Farine de blé française,Sans huile de palme,Moins 40% de sucre
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 66, 'energy_100g': 1866, 'fat_100g': 14, 'fiber_100g': 4.9, 'proteins_100g': 11, 'salt_100g': 0.36, 'saturated-fat_100g': 1.4, 'sodium_100g': 0.144, 'sugars_100g': 18}
#   nutriscore_grade: b
#   nutriscore_score: 0
#   product_name: Biscuit soja orange
# --------------------------------------------------------------------------------
# Product 2: cruesly mélange de noix
# All Data:
#   _id: 3168930010265
#   brands: Quaker
#   categories: Aliments et boissons à base de végétaux,Aliments d'origine végétale,Petit-déjeuners,Céréales et pommes de terre,Céréales et dérivés,Céréales pour petit-déjeuner,Mueslis,Céréales aux fruits à coques,Pépites de céréales croustillantes,Pépites de céréales aux fruits à coques
#   countries: Belgique,France,Polynésie française,Allemagne,Guadeloupe,Italie,Martinique,La Réunion,Slovénie,Espagne,Suisse,Royaume-Uni
#   ingredients_text: _avoine_ complète (32%), _blé_ complet (18%), sirop de glucose, huile de tournesol, sucre, _amandes_ grillées (4,2%), _noisettes_ (4%), oligofructose, _noix de Pécan_ (1,5%), farine de _blé_, farine de riz, _noix du Brésil_ (1%), miel, arômes naturels, antioxydant (tocophérol).
#   labels: Sans arômes artificiels,Sans conservateurs,Point Vert,Sans colorants,Nutriscore,Nutriscore A,Triman
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 57, 'energy_100g': 1913, 'fat_100g': 19, 'fiber_100g': 10, 'proteins_100g': 8.5, 'salt_100g': 0, 'saturated-fat_100g': 2, 'sodium_100g': 0, 'sugars_100g': 12}
#   nutriscore_grade: a
#   nutriscore_score: -2
#   product_name: cruesly mélange de noix
# --------------------------------------------------------------------------------
# Product 3: Alvalle Gazpacho l'original
# All Data:
#   _id: 3168930163480
#   brands: Alvalle,Pepsico
#   categories: Aliments et boissons à base de végétaux, Aliments d'origine végétale, Aliments à base de fruits et de légumes, Plats préparés, Soupes, Soupes de légumes, Soupes froides, Gaspacho
#   countries: France
#   ingredients_text: Tomate,poivron,concombre,oignon, huile d'olive vierge extra (2,2%),vinaigre de vin,sel,ail,jus de citron,teneur en légumes: 94%
#   labels: Sans gluten, Sans conservateurs, en:FSC, Point Vert, Sans additifs, Sans colorants, Nutriscore, Nutriscore A, Triman, Emballage Carbon neutral, FSC-C081801
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 3.5, 'energy_100g': 168, 'fat_100g': 2.2, 'fiber_100g': 1.2, 'proteins_100g': 0.9, 'salt_100g': 0.62, 'saturated-fat_100g': 0.4, 'sodium_100g': 0.248, 'sugars_100g': 3.3}
#   nutriscore_grade: a
#   nutriscore_score: -4
#   product_name: Alvalle Gazpacho l'original
# --------------------------------------------------------------------------------
# Product 4: Oméga 3® Doux
# All Data:
#   _id: 3366321051983
#   brands: St Hubert,St hubert omega 3
#   categories: Aliments et boissons à base de végétaux, Aliments d'origine végétale, Matières grasses, Produits à tartiner, Pâtes à tartiner végétales, Produits à tartiner salés, Matières grasses à tartiner, Matières grasses végétales, Margarines, Margarines allégées, Margarines sans sel, Matière grasse végétale douce à teneur réduite en matière grasse, Pâtés végétaux, en:50-63-unsalted-vegetable-fat-margarine-type-high-in-omega-3
#   countries: France,La Réunion,Suisse
#   ingredients_text: Huiles et stéarine végétales 50% (colza 28%, coco, karité, lin 5,7%), eau, émulsifiants (mono et diglycérides d'acides gras, lécithine de SOJA), sel, arômes, stabilisant (pectine), colorant (bêta-carotène), vitamine B1. Traces éventuelles d'ARACHIDES.
#   labels: Omega-3, Point Vert, Fabriqué en France, Sans huile de palme, Nutriscore, Nutriscore C, Triman
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 0, 'energy_100g': 1924, 'fat_100g': 52, 'proteins_100g': 0, 'salt_100g': 0.4125, 'saturated-fat_100g': 17, 'sodium_100g': 0.165, 'sugars_100g': 0}
#   nutriscore_grade: c
#   nutriscore_score: 10
#   product_name: Oméga 3® Doux
# --------------------------------------------------------------------------------
# Product 5: 1848 Chocolat en poudre
# All Data:
#   _id: 16256866
#   brands: Poulain
#   categories: Boissons, Cacao et dérivés, Cacaos et chocolats en poudre, Boissons instantanées, Chocolats en poudre, en:B
#   countries: France,Martinique
#   ingredients_text: Cacao maigre (11% de beurre de cacao) en poudre (50%), sucre, arôme. Peut contenir lait et soja.
#   labels: Point Vert, Triman, en:32
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 55, 'energy_100g': 1475, 'fat_100g': 5.8, 'fiber_100g': 17, 'proteins_100g': 11, 'salt_100g': 0.02, 'saturated-fat_100g': 3.6, 'sodium_100g': 0.008, 'sugars_100g': 47}
#   nutriscore_grade: a
#   nutriscore_score: -1
#   product_name: 1848 Chocolat en poudre
# --------------------------------------------------------------------------------
# Product 6: Fresh Square 0% - Plain
# All Data:
#   _id: 3480341000674
#   brands: Elle & Vire,Savencia
#   categories: Dairies,Fermented foods,Fermented milk products,Cheeses,Cream cheeses,Fromages,Fromages à la crème,Produits fermentés,Produits laitiers,Produits laitiers fermentés
#   countries: France
#   ingredients_text: Skimmed milk (origin: France), salt, lactic ferments.
#   labels: Source of proteins, French milk, High proteins, Made in France, en:no-fat
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 1.5, 'energy_100g': 326, 'fat_100g': 0.2, 'proteins_100g': 17.5, 'salt_100g': 1.5, 'saturated-fat_100g': 0.1, 'sodium_100g': 0.6, 'sugars_100g': 1.5}
#   nutriscore_grade: b
#   nutriscore_score: 1
#   product_name: Fresh Square 0% - Plain
# --------------------------------------------------------------------------------
# Product 7: Nutella
# All Data:
#   _id: 3017620422003
#   brands: Nutella,Ferrero
#   categories: Breakfasts,Spreads,Sweet spreads,fr:Pâtes à tartiner,Hazelnut spreads,Chocolate spreads,Cocoa and hazelnuts spreads
#   countries: Belgium,France,Germany,Italy,Luxembourg,Morocco,Netherlands,Philippines,Poland,Romania,Spain,Switzerland,United Kingdom,United States
#   ingredients_text: Sucre, huile de palme, NOISETTES 13%, cacao maigre 7,4%, LAIT écrémé en poudre 6,6%, LACTOSERUM en poudre, émulsifiants: lécithines [SOJA), vanilline. Sans gluten.
#   labels: No gluten,No preservatives,No hydrogenated fats,Triman
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 57.5, 'energy_100g': 2252, 'fat_100g': 30.9, 'proteins_100g': 6.3, 'salt_100g': 0.107, 'saturated-fat_100g': 10.6, 'sodium_100g': 0.0428, 'sugars_100g': 56.3}
#   nutriscore_grade: e
#   nutriscore_score: 26
#   product_name: Nutella
# --------------------------------------------------------------------------------
# Product 8: Ohne Zucker Hafer
# All Data:
#   _id: 5411188124689
#   brands: Alpro
#   categories: Beverages and beverages preparations,Plant-based foods and beverages,Beverages,Plant-based foods,Cereals and potatoes,Dairy substitutes,Cereals and their products,Milk substitutes,Plant-based beverages,Plant-based milk alternatives,Cereal-based drinks,Oat-based drinks
#   countries: Belgium,Finland,France,Germany,Hungary,Italy,Netherlands,Portugal,Spain,Switzerland,Turkey,United Kingdom
#   ingredients_text: _Haferbasis_ (97,0%) (Wasser, _Hafer_ (8,3%)), löslicher Mais-Ballaststoff, Sonnenblumenöl, Calcium (Calciumcarbonat), Meersalz, Stabilisator (Gellan), Vitamine B2, B12, D2.
#   labels: Low or no sugar,Vegetarian,Vegan,Certified B Corporation,European Vegetarian Union,European Vegetarian Union Vegan,FSC,FSC Mix,Green Dot,High in calcium,No colorings,No milk,No sugar,Nutriscore,Nutriscore Grade A,With Sunflower oil,es:Recicla amarillo,es:Recicla marrón
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 5.8, 'energy_100g': 167, 'fat_100g': 1.5, 'fiber_100g': 1.2, 'proteins_100g': 0.2, 'salt_100g': 0.11, 'saturated-fat_100g': 0.2, 'sodium_100g': 0.044, 'sugars_100g': 0}
#   nutriscore_grade: a
#   nutriscore_score: -1
#   product_name: Ohne Zucker Hafer
# --------------------------------------------------------------------------------
# Product 9: Walnusskerne
# All Data:
#   _id: 20005733
#   brands: Alesto,Lidl
#   categories: Plantaardige levensmiddelen en dranken,Plantaardige levensmiddelen,Noten en -producten,Noten,Gepelde noten,Walnoten,Gepelde walnoten
#   countries: Oostenrijk,België,Bulgarije,Denemarken,Frankrijk,Duitsland,Italië,Nederland,Polen,Portugal,Spanje
#   ingredients_text: Walnusskerne.
#   labels: Geen of weinig zout,Omega 3,Rijk aan Omega 3,Zonder toegevoegd zout,Nutriscore,Nutriscore A,Triman
#   nova_group: 1
#   nutriments: {'carbohydrates_100g': 3.7, 'energy_100g': 2979, 'fat_100g': 69.1, 'fiber_100g': 6.8, 'proteins_100g': 15.5, 'salt_100g': 0.02, 'saturated-fat_100g': 6.8, 'sodium_100g': 0.008, 'sugars_100g': 3}
#   nutriscore_grade: a
#   nutriscore_score: -1
#   product_name: Walnusskerne
# --------------------------------------------------------------------------------
# Product 10: Le Beurre Tendre Doux
# All Data:
#   _id: 3451790988677
#   brands: Elle & Vire,Savencia
#   categories: Dairies, Fats, Spreads, Spreadable fats, Animal fats, Milkfat, Dairy-spread, Butters, Unsalted butters, Sweet cream butters, Butter-82-fat-unsalted-easy-to-spread, fr:Beurres tendres
#   countries: Canada,France,Suisse,États-Unis
#   ingredients_text: cream (origin france), milk fat , lactic ferments,
#   labels: Point Vert,Fabriqué en France,Triman,en:Sans additifs,Médaille d'argent du concours général agricole 2009
#   nova_group: 2
#   nutriments: {'carbohydrates_100g': 0.8, 'energy_100g': 3060, 'fat_100g': 82, 'fiber_100g': 0, 'proteins_100g': 0.7, 'salt_100g': 0.05, 'saturated-fat_100g': 57, 'sodium_100g': 0.02, 'sugars_100g': 0.8}
#   nutriscore_grade: e
#   nutriscore_score: 19
#   product_name: Le Beurre Tendre Doux
# --------------------------------------------------------------------------------
# Product 11: Crema de cacahuete
# All Data:
#   _id: 8480000671400
#   brands: Hacendado
#   categories: Alimentos e bebidas à base de plantas,Alimentos à base de plantas,Legumes e seus produtos,Produtos para barrar,Pequenos alomoços,Nozes e seus produtos,Produtos para barrar à base de plantas,Doces para barrar,Purés de óleo de sementes,Manteigas de legumes,Manteiga de frutos secos,Manteigas de amendoim
#   countries: Espanha
#   ingredients_text: _Cacahuetes_ (Arachis hypogaea) 100%.
#   labels: Do not freeze, Green Dot, en:no-gluten
#   nova_group: 1
#   nutriments: {'carbohydrates_100g': 7, 'energy_100g': 2558, 'fat_100g': 50, 'fiber_100g': 9.9, 'proteins_100g': 30, 'salt_100g': 0.02, 'saturated-fat_100g': 6.8, 'sodium_100g': 0.008, 'sugars_100g': 3.6}
#   nutriscore_grade: a
#   nutriscore_score: -2
#   product_name: Crema de cacahuete
# --------------------------------------------------------------------------------
# Product 12: Skyr Nature
# All Data:
#   _id: 3329770077003
#   brands: Yoplait
#   categories: Produits laitiers,Produits fermentés,Produits laitiers fermentés,Desserts,Desserts lactés,Desserts lactés fermentés,Skyrs,en:Desserts lactés,en:Desserts lactés fermentés,en:Desserts lactés fermentés nature,en:Produits fermentés,en:Produits laitiers,en:Produits laitiers fermentés,en:Skyrs nature
#   countries: France
#   ingredients_text: Yaourt maigre (Lait). Lait d'origine France. La présence éventuelle de petit lait dans le pot est naturelle. Fat free strained yogurt Ingredients: Fat free yogurt (Milk). For allergens: see ingredients in bold and underlined. The presence of whey is natural.
#   labels: Lait Français,Nutriscore,Nutriscore A,Triman
#   nutriments: {'carbohydrates_100g': 3.6, 'energy_100g': 241, 'fat_100g': 0.5, 'fiber_100g': 0, 'proteins_100g': 9.5, 'salt_100g': 0.14, 'saturated-fat_100g': 0.1, 'sodium_100g': 0.056, 'sugars_100g': 3.6}
#   nutriscore_grade: a
#   nutriscore_score: -5
#   product_name: Skyr Nature
# --------------------------------------------------------------------------------
# Product 13: Oat Drink Barista Edition
# All Data:
#   _id: 7394376616228
#   brands: Oatly
#   categories: Plant-based foods and beverages,Cereals and potatoes,Dairy substitutes,Milk substitutes,Plant-based beverages,Plant-based milk alternatives,Cereal-based drinks,Oat-based drinks
#   countries: An Fhraing,A' Ghearmailt,Poblachd na h-Èireann,An Rìoghachd Aonaichte
#   ingredients_text: water,  oats  10%, rapeseed oil, acidity regulator (dipotassium phosphate), minerals (calcium carbonate, potassium iodide), salt, vitamins (d2, riboflavin and b12),
#   labels: en:Vegetarian,en:Vegan,en:Carbon footprint,en:FSC,en:FSC Mix,en:No milk,en:No soy,en:Natural sugars from oats
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 7.1, 'energy_100g': 255, 'fat_100g': 3, 'fiber_100g': 0.8, 'proteins_100g': 1.1, 'salt_100g': 0.0975, 'saturated-fat_100g': 0.3, 'sodium_100g': 0.039, 'sugars_100g': 4}
#   nutriscore_grade: b
#   nutriscore_score: 0
#   product_name: Oat Drink Barista Edition
# --------------------------------------------------------------------------------
# Product 14: Pulco Zitrone
# All Data:
#   _id: 3225350000501
#   brands: Pulco,Schweppes International Limited,Orangina Schweppes France
#   categories: Beverages and beverages preparations, Beverages, en:flavoured-syrups
#   countries: Belgique,France,Allemagne,Suisse
#   ingredients_text: Wasser, konzentrierter Saft: Zitrone 35,5% und Orange 4,5% (entspricht 40% rekonstituiertem Saft), Zitronenpulpe 5%, Säuerungsmittel: Zitronensäure, natürlicher Zitronenextrakt.
#   labels: Bio, Bio européen, Sans conservateurs, Sans sucre ajouté, Sans colorants, en:Peu ou pas de sucre, en:Sans colorants, en:Sans conservateurs, en:Sans sucre ajouté
#   nova_group: 1
#   nutriments: {'carbohydrates_100g': 0.8, 'energy_100g': 49.5, 'fat_100g': 0, 'fiber_100g': 5, 'proteins_100g': 0.1, 'salt_100g': 0.005, 'saturated-fat_100g': 0, 'sodium_100g': 0.002, 'sugars_100g': 0.4}
#   nutriscore_grade: c
#   nutriscore_score: 2
#   product_name: Pulco Zitrone
# --------------------------------------------------------------------------------
# Product 15: 70% Cacao noir intense
# All Data:
#   _id: 3046920022651
#   brands: Lindt
#   categories: Imbiss,Süßer Snack,Kakao und Kakaoprodukte,Schokoladen,Bitterschokoladen,en:Dark chocolate bar,en:Dark chocolate bar with more than 70% cocoa
#   countries: Algerien,Belgien,Tschechien,Frankreich,Deutschland,Guadeloupe,Italien,Marokko,Réunion,Spanien,Schweiz
#   ingredients_text: Pâte de cacao, sucre, beurre de cacao, vanille.
#   labels: Ohne Konservierungsstoffe,Hergestellt in Frankreich,Triman
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 34, 'energy_100g': 2350, 'fat_100g': 41, 'proteins_100g': 9.5, 'salt_100g': 0.1, 'saturated-fat_100g': 24, 'sodium_100g': 0.04, 'sugars_100g': 30}
#   nutriscore_grade: e
#   nutriscore_score: 23
#   product_name: 70% Cacao noir intense
# --------------------------------------------------------------------------------
# Product 16: Zarte Haferflocken
# All Data:
#   _id: 20003166
#   brands: Crownfield
#   categories: Plantaardige levensmiddelen en dranken,Plantaardige levensmiddelen,Ontbijten,Granen en aardappels,Granen en graanproducten,Ontbijtgranen,Vlokken,Ontbijtvlokken,en:Rolled flakes,Havermoutvlokken
#   countries: België,Frankrijk,Duitsland,Italië,Nederland,Spanje
#   ingredients_text: 100% Hafervollkornflocken.
#   labels: Duitse Landbouw Stichting,en:Gold medal of the German Agricultural Society,Bron van vezels,en:2014 Gold medal of the German Agricultural Society,Groene Punt,Vezelrijk,Nutriscore,Nutriscore A,Triman,en:verified,es:recicla-azul,fr:medaille-d-or-de-la-societe
#   nova_group: 1
#   nutriments: {'carbohydrates_100g': 58.7, 'energy_100g': 1566, 'fat_100g': 7, 'fiber_100g': 10, 'proteins_100g': 13.5, 'salt_100g': 0.03, 'saturated-fat_100g': 1.3, 'sodium_100g': 0.012, 'sugars_100g': 0.7}
#   nutriscore_grade: a
#   nutriscore_score: -5
#   product_name: Zarte Haferflocken
# --------------------------------------------------------------------------------
# Product 17: Ricoré original
# All Data:
#   _id: 7613035676497
#   brands: Nestlé
#   categories: Boissons et préparations de boissons,Aliments et boissons à base de végétaux,Boissons,Aliments d'origine végétale,Boissons à base de végétaux,Préparations pour boissons,Cafés,Boissons instantanées,en:Instant coffee substitutes,Cafés solubles,Chicorée soluble,Chicorée et café en poudre soluble,Produits déshydratés,Produits lyophilisés à reconstituer
#   countries: France,Allemagne,Suisse
#   ingredients_text: Café soluble 33,2%, fibres de chicorée (oligofructose) 33%, chicorée soluble 30%, sulfate de magnésium.
#   labels: Made in France, Nutriscore, Nutriscore Grade A, Triman, de:Nova Score Note 4, fr:origine-france
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 9.1, 'energy_100g': 577, 'fat_100g': 0.5, 'fiber_100g': 45.3, 'proteins_100g': 2.7, 'salt_100g': 0.23, 'saturated-fat_100g': 0.1, 'sodium_100g': 0.092, 'sugars_100g': 9.1}
#   nutriscore_grade: e
#   nutriscore_score: 12
#   product_name: Ricoré original
# --------------------------------------------------------------------------------
# Product 18: Nestlé Dessert
# All Data:
#   _id: 7613035040823
#   brands: Nestlé,Nestlé Dessert
#   categories: Snacks,Desserts,Sweet snacks,Cocoa and its products,Chocolates,Dark chocolates,Dark chocolate bar,Dark chocolate bar for cooking with more than 40% cocoa
#   countries: Belgium,France,Germany,Réunion,Switzerland
#   ingredients_text: Sucre, pâte de cacao (Afrique de l'Ouest, Amérique du Sud), beurre de cacao, émulsifiant (lécithine), arôme naturel de vanille de Madagascar. Cacao : 53% minimum. Peut contenir : LAIT, FRUITS A COQUE.
#   labels: Nestlé Cocoa Plan,Nutriscore,Nutriscore Grade E,Rainforest Alliance,Triman,fr:Pur beurre de cacao
#   nova_group: 4
#   nutriments: {'carbohydrates_100g': 50.7, 'energy_100g': 2285, 'fat_100g': 34.1, 'fiber_100g': 7.3, 'proteins_100g': 6, 'salt_100g': 0.01, 'saturated-fat_100g': 20.2, 'sodium_100g': 0.004, 'sugars_100g': 46.4}
#   nutriscore_grade: e
#   nutriscore_score: 21
#   product_name: Nestlé Dessert
# --------------------------------------------------------------------------------
# Product 19: wasa
# All Data:
#   _id: 7300400481571
#   brands: Wasa,Barilla
#   categories: Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Pains croustillants
#   countries: France,Guadeloupe,Italie,Suisse
#   ingredients_text: Farine complète de SEIGLE (110 g*), sel. *en g pour 100 g de produit. Peut contenir des traces de LUPIN, LAIT, MOUTARDE, GRAINES DE SÉSAME et SOJA.
#   labels: Triman,Co2-compensated
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 62, 'energy_100g': 1423, 'fat_100g': 1.5, 'fiber_100g': 20, 'proteins_100g': 9, 'salt_100g': 1, 'saturated-fat_100g': 0.3, 'sodium_100g': 0.4, 'sugars_100g': 2}
#   nutriscore_grade: a
#   nutriscore_score: -2
#   product_name: wasa
# --------------------------------------------------------------------------------
# Product 20: Noir Excellence 90%
# All Data:
#   _id: 3046920029759
#   brands: Lindt
#   categories: Lanches comida,Lanches doces,Cacau e derivados,Chocolates,Chocolates amargos,en:Extra fine dark chocolates
#   countries: Argélia,Bélgica,República Checa,Finlândia,França,Polinésia Francesa,Alemanha,Itália,Maurícia,Marrocos,Países Baixos,Reunião,Singapura,Espanha,Suécia,Suíça,Reino Unido
#   ingredients_text: cocoa mass, cocoa butter, low-fat cocoa, sugar, vanilla,
#   labels: Ponto Verde,Triman
#   nova_group: 3
#   nutriments: {'carbohydrates_100g': 14, 'energy_100g': 2483, 'fat_100g': 55, 'proteins_100g': 10, 'salt_100g': 0.03, 'saturated-fat_100g': 30, 'sodium_100g': 0.012, 'sugars_100g': 7}
#   nutriscore_grade: d
#   nutriscore_score: 18
#   product_name: Noir Excellence 90%
# --------------------------------------------------------------------------------

# %%
# Function to display essential fields for randomly sampled products
def inspect_sampled_products_focused(products, sample_size=20):
    if not products:
        print("No products available to inspect.")
        return

    # Randomly sample products (ensure we don't sample more than available)
    sample_size = min(sample_size, len(products))
    sampled_products = random.sample(products, sample_size)

    print(f"Displaying detailed data for {sample_size} randomly sampled products:\n")
    for i, product in enumerate(sampled_products, start=1):
        product_name = product.get("product_name", "Unknown Product")
        brands = product.get("brands", "Not Specified")
        categories = product.get("categories", "Not Specified")
        countries = product.get("countries", "Not Specified")
        ingredients = product.get("ingredients_text", "Not Specified")
        labels = product.get("labels", "Not Specified")
        nutriscore = product.get("nutriscore_grade", "Not Specified")
        nova_group = product.get("nova_group", "Not Specified")
        nutriments = product.get("nutriments", {})
        
        print(f"Product {i}: {product_name}")
        print(f"  Brands: {brands}")
        print(f"  Categories: {categories}")
        print(f"  Countries: {countries}")
        print(f"  Ingredients: {ingredients}")
        print(f"  Labels: {labels}")
        print(f"  NutriScore Grade: {nutriscore}")
        print(f"  Nova Group: {nova_group}")
        print("  Nutrition Data:")
        for key in ["energy_100g", "fat_100g", "saturated-fat_100g", 
                    "carbohydrates_100g", "sugars_100g", "fiber_100g", 
                    "proteins_100g", "salt_100g", "sodium_100g"]:
            print(f"    {key.replace('_', ' ').title()}: {nutriments.get(key, 'Not Available')}")
        print("-" * 80)

# Inspect a sample of 20 products with focused fields
inspect_sampled_products_focused(products, sample_size=20)
# Out:
# Displaying detailed data for 20 randomly sampled products:
#
# Product 1: Eau de source
#   Brands: Cristaline
#   Categories: Boissons, Eaux, Eaux de sources, Boissons sans sucre ajouté
#   Countries: Belgique,Côte d'Ivoire,France,Luxembourg,Mali,Martinique,Russie,Suisse,Royaume-Uni
#   Ingredients: Eau de source
#   Labels: Triman, Sans Nitrates
#   NutriScore Grade: a
#   Nova Group: 1
#   Nutrition Data:
#     Energy 100G: 0
#     Fat 100G: 0
#     Saturated-Fat 100G: 0
#     Carbohydrates 100G: 0
#     Sugars 100G: Not Available
#     Fiber 100G: Not Available
#     Proteins 100G: Not Available
#     Salt 100G: 0.000475
#     Sodium 100G: 0.00019
# --------------------------------------------------------------------------------
# Product 2: hepar
#   Brands: Hépar,Nestlé Waters,Nestlé
#   Categories: Boissons,Eaux,Eaux de sources,Eaux minérales,Eaux minérales naturelles,Eau minérale naturelle non gazeuse
#   Countries: Belgique,France
#   Ingredients: Pour 100ml : Calcium = 549mg / Magnésium = 119mg / Sodium = 14.2mg / Sulfate = 1530mg / Hydrogénocarbonate = 387.3mg / Nitrate = 4.3mg / Résidu sec à 180°C = 2513mg / pH 7.2
#   Labels: Point Vert,Nutriscore,Nutriscore A,Triman
#   NutriScore Grade: a
#   Nova Group: Not Specified
#   Nutrition Data:
#     Energy 100G: 0.0001
#     Fat 100G: 0.0001
#     Saturated-Fat 100G: 0.0001
#     Carbohydrates 100G: 0.0001
#     Sugars 100G: 0.0001
#     Fiber 100G: 0.0001
#     Proteins 100G: 0.0001
#     Salt 100G: 0.0001
#     Sodium 100G: 4e-05
# --------------------------------------------------------------------------------
# Product 3: Fresh Square 0% - Plain
#   Brands: Elle & Vire,Savencia
#   Categories: Dairies,Fermented foods,Fermented milk products,Cheeses,Cream cheeses,Fromages,Fromages à la crème,Produits fermentés,Produits laitiers,Produits laitiers fermentés
#   Countries: France
#   Ingredients: Skimmed milk (origin: France), salt, lactic ferments.
#   Labels: Source of proteins, French milk, High proteins, Made in France, en:no-fat
#   NutriScore Grade: b
#   Nova Group: 3
#   Nutrition Data:
#     Energy 100G: 326
#     Fat 100G: 0.2
#     Saturated-Fat 100G: 0.1
#     Carbohydrates 100G: 1.5
#     Sugars 100G: 1.5
#     Fiber 100G: Not Available
#     Proteins 100G: 17.5
#     Salt 100G: 1.5
#     Sodium 100G: 0.6
# --------------------------------------------------------------------------------
# Product 4: Nutella
#   Brands: Nutella,Ferrero
#   Categories: Breakfasts,Spreads,Sweet spreads,fr:Pâtes à tartiner,Hazelnut spreads,Chocolate spreads,Cocoa and hazelnuts spreads
#   Countries: Belgium,France,Germany,Italy,Luxembourg,Morocco,Netherlands,Philippines,Poland,Romania,Spain,Switzerland,United Kingdom,United States
#   Ingredients: Sucre, huile de palme, NOISETTES 13%, cacao maigre 7,4%, LAIT écrémé en poudre 6,6%, LACTOSERUM en poudre, émulsifiants: lécithines [SOJA), vanilline. Sans gluten.
#   Labels: No gluten,No preservatives,No hydrogenated fats,Triman
#   NutriScore Grade: e
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 2252
#     Fat 100G: 30.9
#     Saturated-Fat 100G: 10.6
#     Carbohydrates 100G: 57.5
#     Sugars 100G: 56.3
#     Fiber 100G: Not Available
#     Proteins 100G: 6.3
#     Salt 100G: 0.107
#     Sodium 100G: 0.0428
# --------------------------------------------------------------------------------
# Product 5: RICORE Original
#   Brands: Nestlé,Ricore
#   Categories: Boissons et préparations de boissons,Aliments et boissons à base de végétaux,Boissons,Boissons à base de végétaux,Préparations pour boissons,Boissons instantanées,Chicorée et café en poudre soluble,Aliments
#   Countries: Belgium,France,Morocco,Spain,Switzerland
#   Ingredients: café soluble 33,2%, fibres de chicorée (oligofructose) 33%, chicorée soluble 30%, sulfate de magnésium,
#   Labels: Source of fibre, Sustainable farming, Green Dot, High fibres, Made in France, Magnesium source, Nutriscore, Nutriscore Grade A, UTZ Certified, Triman, fr:origine-france
#   NutriScore Grade: e
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 577
#     Fat 100G: 0.5
#     Saturated-Fat 100G: 0.1
#     Carbohydrates 100G: 9.1
#     Sugars 100G: 9.1
#     Fiber 100G: 45.3
#     Proteins 100G: 2.7
#     Salt 100G: 0.23
#     Sodium 100G: 0.092
# --------------------------------------------------------------------------------
# Product 6: Crema de cacahuete
#   Brands: Hacendado
#   Categories: Alimentos e bebidas à base de plantas,Alimentos à base de plantas,Legumes e seus produtos,Produtos para barrar,Pequenos alomoços,Nozes e seus produtos,Produtos para barrar à base de plantas,Doces para barrar,Purés de óleo de sementes,Manteigas de legumes,Manteiga de frutos secos,Manteigas de amendoim
#   Countries: Espanha
#   Ingredients: _Cacahuetes_ (Arachis hypogaea) 100%.
#   Labels: Do not freeze, Green Dot, en:no-gluten
#   NutriScore Grade: a
#   Nova Group: 1
#   Nutrition Data:
#     Energy 100G: 2558
#     Fat 100G: 50
#     Saturated-Fat 100G: 6.8
#     Carbohydrates 100G: 7
#     Sugars 100G: 3.6
#     Fiber 100G: 9.9
#     Proteins 100G: 30
#     Salt 100G: 0.02
#     Sodium 100G: 0.008
# --------------------------------------------------------------------------------
# Product 7:
#   Brands: Alesto
#   Categories: Alimentos y bebidas de origen vegetal,Alimentos de origen vegetal,Frutos de cáscara y derivados,Frutos de cáscara,Anacardos
#   Countries: Austria,Bélgica,Croacia,Francia,Alemania,Hungría,Italia,España,Suecia,Suiza,Reino Unido
#   Ingredients: Cashewkerne 100%
#   Labels: Vegetarian, Source of proteins, Vegan, European Vegetarian Union, European Vegetarian Union Vegan, Green Dot, High proteins, Magnesium source, No palm oil, Packaged in Germany, Rich in unsaturated fatty acids, en:no-added-salt
#   NutriScore Grade: d
#   Nova Group: Not Specified
#   Nutrition Data:
#     Energy 100G: 2510
#     Fat 100G: 47.6
#     Saturated-Fat 100G: 9
#     Carbohydrates 100G: 19.8
#     Sugars 100G: 6.5
#     Fiber 100G: 5.2
#     Proteins 100G: 20.5
#     Salt 100G: 0.02
#     Sodium 100G: 0.008
# --------------------------------------------------------------------------------
# Product 8: Coca-Cola
#   Brands: Coca-Cola
#   Categories: Getränke und Getränkezubereitungen,Getränke,Kohlensäurehaltige Getränke,Erfrischungsgetränke,Cola
#   Countries: Frankreich,Deutschland,Litauen,Vereinigtes Königreich
#   Ingredients: water, sugar, carbon dioxide, colour E150d, acid: phosphoric acid, natural flavourings, flavour caffeine
#   Labels:
#   NutriScore Grade: e
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 180
#     Fat 100G: 0
#     Saturated-Fat 100G: 0
#     Carbohydrates 100G: 10.6
#     Sugars 100G: 10.6
#     Fiber 100G: Not Available
#     Proteins 100G: 0
#     Salt 100G: 0
#     Sodium 100G: 0
# --------------------------------------------------------------------------------
# Product 9: Fourrés - Chocolat Noir
#   Brands: Bjorg
#   Categories: Snacks, Snacks sucrés, Biscuits et gâteaux, Biscuits, Biscuits au chocolat, Biscuits fourrés, Biscuits au chocolat noir
#   Countries: France,Luxembourg,Switzerland
#   Ingredients: Farine de blé 39 %, chocolat noir 25 % (pâte de cacao, sucre de canne, beurre de cacao), sucre de canne roux non raffiné, farine complète de blé 15 %, huile de tournesol oléique, arôme naturel de vanille, lait écrémé en poudre, sel de mer, poudres à lever : carbonates d'ammonium, carbonates de sodium, épaississant : gomme d'acacia, antioxydant : extraits de romarin.
#   Labels: Bio, Bio européen, Agriculture non UE, Entreprise B certifiée, Agriculture UE, Agriculture UE/Non UE, FR-BIO-01, Sans huile de palme, Nutriscore, Nutriscore D, Pur beurre de cacao, AB Agriculture Biologique
#   NutriScore Grade: d
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 2017
#     Fat 100G: 20
#     Saturated-Fat 100G: 6.9
#     Carbohydrates 100G: 65
#     Sugars 100G: 27
#     Fiber 100G: 5.3
#     Proteins 100G: 7.6
#     Salt 100G: 0.49
#     Sodium 100G: 0.196
# --------------------------------------------------------------------------------
# Product 10: Pain AMS complet
#   Brands: Harrys
#   Categories: Aliments et boissons à base de végétaux, Aliments d'origine végétale, Céréales et pommes de terre, Pains, Pains de mie, Pains complets, Pains de mie complet
#   Countries: Belgien,Frankreich,Guadeloupe,Schweiz
#   Ingredients: Farine complète de blé 38%, eau, farine de blé, huile de colza, sucre, arôme (contient alcool), sel, gluten de blé, farine de seigle maltée, vinaigre, levure, extrait d'acérola. peut contenir des traces d'oeufs, soja, lait, fruits a coque, graines de sésame.
#   Labels: Source de fibres alimentaires, Point Vert, Riche en fibres, Fabriqué en France, Sans additifs, Sans huile de palme, Nutriscore, Nutriscore B, Blé français, Terracycle
#   NutriScore Grade: b
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 1100
#     Fat 100G: 4.5
#     Saturated-Fat 100G: 0.4
#     Carbohydrates 100G: 41.7
#     Sugars 100G: 4.9
#     Fiber 100G: 7.2
#     Proteins 100G: 7.7
#     Salt 100G: 1.2
#     Sodium 100G: 0.48
# --------------------------------------------------------------------------------
# Product 11: Coke zero
#   Brands: Coca Cola
#   Categories: Boissons,Boissons gazeuses,Boissons édulcorées,Sodas,Boissons light,Boissons sans alcool,Sodas au cola,Sodas light,Sodas au cola light
#   Countries: Belgique,France,Allemagne,Hongrie,Italie,Espagne,Suisse,États-Unis
#   Ingredients: eau gazéifiée : colorant : E150d , acidifiant : acide phosphorique, édulcorants : aspartame, acésulfame-K , arômes naturels (caféine), correcteur d'acidité, citrates de sodium
#   Labels: Fabriqué en France,Arômes naturels,Sans matière grasse hydrogénée,Triman
#   NutriScore Grade: b
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 1.4
#     Fat 100G: 0
#     Saturated-Fat 100G: 0
#     Carbohydrates 100G: 0
#     Sugars 100G: 0
#     Fiber 100G: 0
#     Proteins 100G: 0
#     Salt 100G: 0.02
#     Sodium 100G: 0.008
# --------------------------------------------------------------------------------
# Product 12: Levure de bière
#   Brands: Gerblé
#   Categories: Condiments,Additifs alimentaires,Levure alimentaire,Levures de bière
#   Countries: France,La Réunion,Suisse
#   Ingredients: Levure de bière 93%, extrait de malt d'orge 7%
#   Labels: Source de fibres alimentaires,Source de protéines,Point Vert,Riche en fibres,Riche en protéines,Fabriqué en France,Nutriscore,Nutriscore A,Source de phosphore,Riche en vitamine B,Riche en vitamine B1,Riche en vitamine B9,Origine France,Triman
#   NutriScore Grade: not-applicable
#   Nova Group: 1
#   Nutrition Data:
#     Energy 100G: 1356
#     Fat 100G: 4.6
#     Saturated-Fat 100G: 0.8
#     Carbohydrates 100G: 12
#     Sugars 100G: 1.2
#     Fiber 100G: 25
#     Proteins 100G: 46
#     Salt 100G: 0.32
#     Sodium 100G: 0.128
# --------------------------------------------------------------------------------
# Product 13: Tartine croustillante Authentique
#   Brands: Wasa,Barilla
#   Categories: Aliments et boissons à base de végétaux,Aliments d'origine végétale,Snacks,Céréales et pommes de terre,Pains,Pains croustillants
#   Countries: France,Italie,Espagne,Suisse
#   Ingredients: Farine complète de SEIGLE (77 g*), farine de SEIGLE (28 g*), levure, sel. Peut contenir des traces de LAIT et de GRAINES DE SÉSAME. *en g pour 100 g de produit.
#   Labels: Bio,Point Vert,Triman
#   NutriScore Grade: a
#   Nova Group: 3
#   Nutrition Data:
#     Energy 100G: 1415
#     Fat 100G: 1.5
#     Saturated-Fat 100G: 0.4
#     Carbohydrates 100G: 62
#     Sugars 100G: 1
#     Fiber 100G: 19
#     Proteins 100G: 9
#     Salt 100G: 1
#     Sodium 100G: 0.4
# --------------------------------------------------------------------------------
# Product 14: Coca-Cola
#   Brands: Coca-Cola
#   Categories: Boissons et préparations de boissons,Boissons,Boissons gazeuses,Sodas,Boissons gazeuses sans jus de fruit,Sodas au cola,Boissons gazeuses sucrées sans jus de fruit,Boissons avec sucre ajouté
#   Countries: Belgique,France,Allemagne,Hongrie,Italie,Serbie,Espagne,Suisse
#   Ingredients: Eau gazéifiée, sucre, colorant: E150d, acidifiant: acide phosphorique, arômes naturels, arôme caféine.
#   Labels: Fabriqué en France,Triman,Povratna naknada
#   NutriScore Grade: e
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 180
#     Fat 100G: 0
#     Saturated-Fat 100G: 0
#     Carbohydrates 100G: 10.6
#     Sugars 100G: 10.6
#     Fiber 100G: Not Available
#     Proteins 100G: 0
#     Salt 100G: 0
#     Sodium 100G: 0
# --------------------------------------------------------------------------------
# Product 15: Eau de source
#   Brands: Cristaline
#   Categories: Boissons et préparations de boissons,Boissons,Eaux,Eaux de sources
#   Countries: Belgique,Côte d'Ivoire,France,Allemagne,Guadeloupe,Italie,Luxembourg,Mali,Martinique,Nouvelle-Calédonie,Suisse,Royaume-Uni
#   Ingredients: Eau de source
#   Labels: Triman
#   NutriScore Grade: a
#   Nova Group: 1
#   Nutrition Data:
#     Energy 100G: Not Available
#     Fat 100G: Not Available
#     Saturated-Fat 100G: Not Available
#     Carbohydrates 100G: Not Available
#     Sugars 100G: Not Available
#     Fiber 100G: Not Available
#     Proteins 100G: Not Available
#     Salt 100G: Not Available
#     Sodium 100G: Not Available
# --------------------------------------------------------------------------------
# Product 16: cruesly mélange de noix
#   Brands: Quaker
#   Categories: Aliments et boissons à base de végétaux,Aliments d'origine végétale,Petit-déjeuners,Céréales et pommes de terre,Céréales et dérivés,Céréales pour petit-déjeuner,Mueslis,Céréales aux fruits à coques,Pépites de céréales croustillantes,Pépites de céréales aux fruits à coques
#   Countries: Belgique,France,Polynésie française,Allemagne,Guadeloupe,Italie,Martinique,La Réunion,Slovénie,Espagne,Suisse,Royaume-Uni
#   Ingredients: _avoine_ complète (32%), _blé_ complet (18%), sirop de glucose, huile de tournesol, sucre, _amandes_ grillées (4,2%), _noisettes_ (4%), oligofructose, _noix de Pécan_ (1,5%), farine de _blé_, farine de riz, _noix du Brésil_ (1%), miel, arômes naturels, antioxydant (tocophérol).
#   Labels: Sans arômes artificiels,Sans conservateurs,Point Vert,Sans colorants,Nutriscore,Nutriscore A,Triman
#   NutriScore Grade: a
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 1913
#     Fat 100G: 19
#     Saturated-Fat 100G: 2
#     Carbohydrates 100G: 57
#     Sugars 100G: 12
#     Fiber 100G: 10
#     Proteins 100G: 8.5
#     Salt 100G: 0
#     Sodium 100G: 0
# --------------------------------------------------------------------------------
# Product 17: Yeast Extract
#   Brands: Marmite,Unilever
#   Categories: Yeast extract spreads
#   Countries: France,Irlande,Royaume-Uni
#   Ingredients: Yeast extract (contains BARLEY, WHEAT, OATS, RYE), salt, vegetable juice concentrate, vitamins (thiamin, riboflavin, niacin, vitamin B12 and folic acid), natural flavouring (contains CELERY).
#   Labels: Végétarien,Végétalien,en:Verified
#   NutriScore Grade: d
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 1100
#     Fat 100G: 0.5
#     Saturated-Fat 100G: 0.1
#     Carbohydrates 100G: 30
#     Sugars 100G: 1.2
#     Fiber 100G: Not Available
#     Proteins 100G: 34
#     Salt 100G: 10.8
#     Sodium 100G: 4.32
# --------------------------------------------------------------------------------
# Product 18: Excellence 85% Cacao Rich Dark
#   Brands: Lindt
#   Categories: Lanches comida,Lanches doces,Cacau e derivados,Chocolates,Chocolates amargos,en:Dark chocolate bar with more than 70% cocoa,en:Extra fine dark chocolates
#   Countries: Andorra,Áustria,Bélgica,Bulgária,Dinamarca,França,Alemanha,Hungria,Itália,Marrocos,Países Baixos,Nova Zelândia,Polónia,Portugal,Roménia,Rússia,Espanha,Suíça,Reino Unido
#   Ingredients: Cocoa mass, fat-reduced cocoa, cocoa butter, demerara sugar, vanilla.
#   Labels: EAC,Ponto Verde,Fabricado em França,Pura manteiga de cacau,Tidy man
#   NutriScore Grade: e
#   Nova Group: 3
#   Nutrition Data:
#     Energy 100G: 2418
#     Fat 100G: 46
#     Saturated-Fat 100G: 27
#     Carbohydrates 100G: 22
#     Sugars 100G: 15
#     Fiber 100G: Not Available
#     Proteins 100G: 12.5
#     Salt 100G: 0.02
#     Sodium 100G: 0.008
# --------------------------------------------------------------------------------
# Product 19: Skyr Nature
#   Brands: Yoplait
#   Categories: Produits laitiers,Produits fermentés,Produits laitiers fermentés,Desserts,Desserts lactés,Desserts lactés fermentés,Skyrs,en:Desserts lactés,en:Desserts lactés fermentés,en:Desserts lactés fermentés nature,en:Produits fermentés,en:Produits laitiers,en:Produits laitiers fermentés,en:Skyrs nature
#   Countries: France
#   Ingredients: Yaourt maigre (Lait). Lait d'origine France. La présence éventuelle de petit lait dans le pot est naturelle. Fat free strained yogurt Ingredients: Fat free yogurt (Milk). For allergens: see ingredients in bold and underlined. The presence of whey is natural.
#   Labels: Lait Français,Nutriscore,Nutriscore A,Triman
#   NutriScore Grade: a
#   Nova Group: Not Specified
#   Nutrition Data:
#     Energy 100G: 241
#     Fat 100G: 0.5
#     Saturated-Fat 100G: 0.1
#     Carbohydrates 100G: 3.6
#     Sugars 100G: 3.6
#     Fiber 100G: 0
#     Proteins 100G: 9.5
#     Salt 100G: 0.14
#     Sodium 100G: 0.056
# --------------------------------------------------------------------------------
# Product 20: Doux 70% noir subtil
#   Brands: Lindt
#   Categories: Snacks,Sweet snacks,Cocoa and its products,Chocolates,Dark chocolates,Dark chocolate bar with more than 70% cocoa
#   Countries: Australia,Denmark,France,Germany,Morocco,Spain,Switzerland,New Zealand
#   Ingredients: cocoa mass, sugar, cocoa butter, emulsifier (soya lecithin), vanilla, may contain hazelnuts, almonds, milk,
#   Labels: Green Dot,Made in Germany,Triman
#   NutriScore Grade: e
#   Nova Group: 4
#   Nutrition Data:
#     Energy 100G: 2530
#     Fat 100G: 48
#     Saturated-Fat 100G: 29
#     Carbohydrates 100G: 33
#     Sugars 100G: 29
#     Fiber 100G: Not Available
#     Proteins 100G: 6.9
#     Salt 100G: 0.0275
#     Sodium 100G: 0.011
# --------------------------------------------------------------------------------

# %%
# Manually specify all fields from the Open Food Facts data-fields.txt
fields = [
    # General Product Information
    "_id", "product_name", "brands", "categories", "countries", "countries_tags",
    "ingredients_text", "labels", "quantity", "packaging", "additives_tags",
    "allergens", "allergens_tags", "traces", "traces_tags", "ingredients_analysis_tags",
    
    # Nutri-Score and NOVA
    "nutriscore_grade", "nutriscore_score", "nova_group",
    
    # Nutritional Information (100g)
    "nutriments.energy_100g", "nutriments.energy-kj_100g", "nutriments.energy-kcal_100g",
    "nutriments.fat_100g", "nutriments.saturated-fat_100g", "nutriments.trans-fat_100g",
    "nutriments.cholesterol_100g", "nutriments.carbohydrates_100g", "nutriments.sugars_100g",
    "nutriments.fiber_100g", "nutriments.proteins_100g", "nutriments.salt_100g",
    "nutriments.sodium_100g", "nutriments.vitamin-a_100g", "nutriments.vitamin-c_100g",
    "nutriments.calcium_100g", "nutriments.iron_100g", "nutriments.potassium_100g",
    "nutriments.magnesium_100g", "nutriments.phosphorus_100g", "nutriments.zinc_100g",
    "nutriments.copper_100g", "nutriments.manganese_100g", "nutriments.selenium_100g",
    "nutriments.vitamin-d_100g", "nutriments.vitamin-e_100g", "nutriments.vitamin-k_100g",
    "nutriments.thiamin_100g", "nutriments.riboflavin_100g", "nutriments.niacin_100g",
    "nutriments.vitamin-b6_100g", "nutriments.folate_100g", "nutriments.vitamin-b12_100g",
    "nutriments.biotin_100g", "nutriments.pantothenic-acid_100g", "nutriments.water_100g",
    
    # Images and Links
    "image_url", "image_nutrition_url", "image_ingredients_url", "url",
    
    # Miscellaneous
    "environment_impact_level_tags", "ecoscore_grade", "ecoscore_score"
]

# %%
# Function to fetch multiple pages of data
def fetch_all_data(api_url, fields, max_pages=10, page_size=100):
    all_products = []
    for page in range(1, max_pages + 1):  # Fetch up to max_pages
        print(f"Fetching page {page}...")
        params = {
            "action": "process",
            "json": 1,
            "fields": ",".join(fields),  # Include all fields
            "page_size": page_size,
            "page": page
        }
        response = requests.get(api_url, params=params)
        if response.status_code == 200:
            result = response.json()
            products = result.get("products", [])
            all_products.extend(products)
            if len(products) == 0:  # Stop if no more products are returned
                print("No more products found.")
                break
        else:
            print(f"Failed to fetch page {page}. Status code: {response.status_code}")
            break

    print(f"Total products fetched: {len(all_products)}")
    return all_products

# API URL
api_url = "https://world.openfoodfacts.org/cgi/search.pl"

# Fetch all data with all fields
all_products = fetch_all_data(api_url, fields, max_pages=10, page_size=500)
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Total products fetched: 1000

# %%
# Convert fetched products to a Pandas DataFrame
def products_to_dataframe(products):
    if not products:
        print("No products available to create a DataFrame.")
        return pd.DataFrame()
    
    # Normalize nested fields (e.g., nutriments) and convert to DataFrame
    df = pd.json_normalize(products)
    print(f"DataFrame created with {len(df)} rows and {len(df.columns)} columns.")
    return df

# Create a DataFrame from the fetched data
df = products_to_dataframe(all_products)
# Out:
# DataFrame created with 1000 rows and 55 columns.

# %%
# Display the DataFrame and list all included columns
def display_dataframe_with_columns(df, rows=20):
    if df.empty:
        print("DataFrame is empty. Nothing to display.")
    else:
        print(f"Displaying the first {rows} rows of the DataFrame:")
        display(df.head(rows))
        
        print("\nIncluded Columns:")
        for column in df.columns:
            print(f"  - {column}")

# Display the DataFrame with included columns
display_dataframe_with_columns(df, rows=20)
# Out:
# Displaying the first 20 rows of the DataFrame:
#               _id                                     additives_tags  \
# 0   3274080005003                                                 []
# 1   7622210449283  [en:e322, en:e322i, en:e450, en:e450i, en:e500...
# 2   3017620425035                                          [en:e322]
# 3   3175680011480               [en:e322, en:e336, en:e500, en:e503]
# 4   5449000214911                                [en:e150d, en:e338]
# 5   3017620422003                                [en:e322, en:e322i]
# 6        50184453                                                 []
# 7   5449000000996                       [en:e150d, en:e290, en:e338]
# 8   3268840001008                                                 []
# 9   5449000214799     [en:e150d, en:e331, en:e338, en:e950, en:e951]
# 10       54491472                       [en:e150d, en:e290, en:e338]
# 11       20724696                                                 []
# 12  3168930163480                                                 []
# 13       80177173                                          [en:e322]
# 14  3046920022651                                                 []
# 15       80135463                                          [en:e322]
# 16  7300400481588                                                 []
# 17  8002270014901                                                 []
# 18  3046920029759                                                 []
# 19  3046920022606                                                 []
#
#                                 allergens  \
# 0
# 1   en:eggs,en:gluten,en:milk,en:soybeans
# 2             en:milk,en:nuts,en:soybeans
# 3
# 4
# 5             en:milk,en:nuts,en:soybeans
# 6                     en:celery,en:gluten
# 7
# 8
# 9                            fr:Aspartame
# 10
# 11                                en:nuts
# 12
# 13            en:milk,en:nuts,en:soybeans
# 14
# 15            en:milk,en:nuts,en:soybeans
# 16    en:gluten,en:sesame-seeds,fr:Avoine
# 17
# 18
# 19
#
#                                 allergens_tags  \
# 0                                           []
# 1   [en:eggs, en:gluten, en:milk, en:soybeans]
# 2              [en:milk, en:nuts, en:soybeans]
# 3                 [en:gluten, en:sesame-seeds]
# 4                                           []
# 5              [en:milk, en:nuts, en:soybeans]
# 6                       [en:celery, en:gluten]
# 7                                           []
# 8                                           []
# 9                               [fr:aspartame]
# 10                                          []
# 11                                   [en:nuts]
# 12                                          []
# 13             [en:milk, en:nuts, en:soybeans]
# 14                                          []
# 15             [en:milk, en:nuts, en:soybeans]
# 16     [en:gluten, en:sesame-seeds, fr:avoine]
# 17                                          []
# 18                                          []
# 19                                          []
#
#                                  brands  \
# 0                            Cristaline
# 1                           Lu,Mondelez
# 2                               Ferrero
# 3                                Gerblé
# 4                             Coca-Cola
# 5                       Nutella,Ferrero
# 6                      Marmite,Unilever
# 7                             Coca-Cola
# 8                            Cristaline
# 9                             Coca Cola
# 10                            Coca-Cola
# 11                          Alesto,Lidl
# 12                      Alvalle,Pepsico
# 13                      Nutella,Ferrero
# 14                                Lindt
# 15                      Nutella,Ferrero
# 16                         Wasa,Barilla
# 17  San Pellegrino,Nestlé Waters,Nestlé
# 18                                Lindt
# 19                                Lindt
#
#                                            categories  \
# 0   Boissons et préparations de boissons,Boissons,...
# 1          Snacks,Sweet snacks,Cocoa and its products
# 2   Breakfasts,Spreads,Sweet spreads,fr:Pâtes à ta...
# 3   Snacks,Snacks sucrés,Biscuits et gâteaux,Biscu...
# 4   Boissons et préparations de boissons,Boissons,...
# 5   Breakfasts,Spreads,Sweet spreads,fr:Pâtes à ta...
# 6                               Yeast extract spreads
# 7   Getränke und Getränkezubereitungen,Getränke,Ko...
# 8   Boissons, Eaux, Eaux de sources, Boissons sans...
# 9   Boissons,Boissons gazeuses,Boissons édulcorées...
# 10  Beverages and beverages preparations,Beverages...
# 11  Alimentos e bebidas à base de plantas,Alimento...
# 12  Aliments et boissons à base de végétaux, Alime...
# 13  Pequenos alomoços,Produtos para barrar,Doces p...
# 14  Imbiss,Süßer Snack,Kakao und Kakaoprodukte,Sch...
# 15  Alimentos e bebidas à base de plantas,Alimento...
# 16  Plant-based foods and beverages,Plant-based fo...
# 17  Boissons et préparations de boissons,Boissons,...
# 18  Lanches comida,Lanches doces,Cacau e derivados...
# 19  Snacks,Sweet snacks,Cocoa and its products,Cho...
#
#                                             countries  \
# 0   Belgique,Côte d'Ivoire,France,Allemagne,Guadel...
# 1   Algeria,Belgium,France,French Polynesia,German...
# 2   Algeria,Belgium,France,Germany,Guadeloupe,Ital...
# 3                                              France
# 4   Belgique,France,Allemagne,Hongrie,Italie,Serbi...
# 5   Belgium,France,Germany,Italy,Luxembourg,Morocc...
# 6                          France,Irlande,Royaume-Uni
# 7   Frankreich,Deutschland,Litauen,Vereinigtes Kön...
# 8   Belgique,Côte d'Ivoire,France,Luxembourg,Mali,...
# 9   Belgique,France,Allemagne,Hongrie,Italie,Espag...
# 10  Austria,Belgium,Bulgaria,Croatia,France,German...
# 11  Bélgica,Bulgária,França,Alemanha,Grécia,Hungri...
# 12                                             France
# 13  Portugal,Reino Unido,República Checa,Polónia,E...
# 14  Algerien,Belgien,Tschechien,Frankreich,Deutsch...
# 15  Áustria,Bélgica,Bulgária,França,Alemanha,Hungr...
# 16  Belgium,France,Guadeloupe,Italy,Réunion,Spain,...
# 17  Belgique,France,Italie,Luxembourg,Pays-Bas,Suisse
# 18  Argélia,Bélgica,República Checa,Finlândia,Fran...
# 19  Austria,Belgium,France,Germany,Italy,Morocco,N...
#
#                                        countries_tags  ecoscore_grade  \
# 0   [en:belgium, en:cote-d-ivoire, en:france, en:g...  not-applicable
# 1   [en:algeria, en:belgium, en:france, en:french-...         unknown
# 2   [en:algeria, en:belgium, en:france, en:germany...               d
# 3                                         [en:france]               c
# 4   [en:belgium, en:france, en:germany, en:hungary...  not-applicable
# 5   [en:belgium, en:france, en:germany, en:italy, ...               d
# 6          [en:france, en:ireland, en:united-kingdom]         unknown
# 7   [en:france, en:germany, en:lithuania, en:unite...  not-applicable
# 8   [en:belgium, en:cote-d-ivoire, en:france, en:l...  not-applicable
# 9   [en:belgium, en:france, en:germany, en:hungary...  not-applicable
# 10  [en:austria, en:belgium, en:bulgaria, en:croat...  not-applicable
# 11  [en:belgium, en:bulgaria, en:france, en:german...         unknown
# 12                                        [en:france]               a
# 13  [en:czech-republic, en:denmark, en:estonia, en...               d
# 14  [en:algeria, en:belgium, en:czech-republic, en...               e
# 15  [en:austria, en:belgium, en:bulgaria, en:franc...               e
# 16  [en:belgium, en:france, en:guadeloupe, en:ital...         unknown
# 17  [en:belgium, en:france, en:italy, en:luxembour...  not-applicable
# 18  [en:algeria, en:belgium, en:czech-republic, en...               e
# 19  [en:austria, en:belgium, en:france, en:germany...               e
#
#    environment_impact_level_tags  ... nutriments.vitamin-c_100g  \
# 0                             []  ...                       NaN
# 1                             []  ...                       NaN
# 2                             []  ...                       NaN
# 3                             []  ...                       NaN
# 4                             []  ...                       NaN
# 5                             []  ...                       NaN
# 6                             []  ...                       NaN
# 7                             []  ...                       NaN
# 8                             []  ...                       NaN
# 9                             []  ...                       NaN
# 10                            []  ...                       NaN
# 11                            []  ...                       NaN
# 12                           NaN  ...                       NaN
# 13                            []  ...                       NaN
# 14                           NaN  ...                       NaN
# 15                            []  ...                       NaN
# 16                            []  ...                       NaN
# 17                            []  ...                       NaN
# 18                            []  ...                       NaN
# 19                            []  ...                       NaN
#
#    nutriments.vitamin-d_100g nutriments.phosphorus_100g  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN                        NaN
# 14                       NaN                        NaN
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
#
#    nutriments.pantothenic-acid_100g  nutriments.trans-fat_100g  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# 5                               NaN                        NaN
# 6                               NaN                        NaN
# 7                               NaN                        NaN
# 8                               NaN                        NaN
# 9                               NaN                        NaN
# 10                              NaN                        NaN
# 11                              NaN                        NaN
# 12                              NaN                        NaN
# 13                              NaN                        NaN
# 14                              NaN                        NaN
# 15                              NaN                        NaN
# 16                              NaN                        NaN
# 17                              NaN                        NaN
# 18                              NaN                        NaN
# 19                              NaN                        NaN
#
#    nutriments.cholesterol_100g  nutriments.vitamin-a_100g  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# 6                          NaN                        NaN
# 7                          NaN                        NaN
# 8                          NaN                        NaN
# 9                          NaN                        NaN
# 10                         NaN                        NaN
# 11                         NaN                        NaN
# 12                         NaN                        NaN
# 13                         NaN                        NaN
# 14                         NaN                        NaN
# 15                         NaN                        NaN
# 16                         NaN                        NaN
# 17                         NaN                        NaN
# 18                         NaN                        NaN
# 19                         NaN                        NaN
#
#    nutriments.manganese_100g nutriments.selenium_100g  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# 5                        NaN                      NaN
# 6                        NaN                      NaN
# 7                        NaN                      NaN
# 8                        NaN                      NaN
# 9                        NaN                      NaN
# 10                       NaN                      NaN
# 11                       NaN                      NaN
# 12                       NaN                      NaN
# 13                       NaN                      NaN
# 14                       NaN                      NaN
# 15                       NaN                      NaN
# 16                       NaN                      NaN
# 17                       NaN                      NaN
# 18                       NaN                      NaN
# 19                       NaN                      NaN
#
#    nutriments.vitamin-k_100g
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
#
# [20 rows x 55 columns]
# Included Columns:
#   - _id
#   - additives_tags
#   - allergens
#   - allergens_tags
#   - brands
#   - categories
#   - countries
#   - countries_tags
#   - ecoscore_grade
#   - environment_impact_level_tags
#   - image_url
#   - ingredients_analysis_tags
#   - ingredients_text
#   - labels
#   - nova_group
#   - nutriscore_grade
#   - nutriscore_score
#   - packaging
#   - product_name
#   - quantity
#   - traces
#   - traces_tags
#   - url
#   - nutriments.carbohydrates_100g
#   - nutriments.energy-kcal_100g
#   - nutriments.energy-kj_100g
#   - nutriments.energy_100g
#   - nutriments.fat_100g
#   - nutriments.fiber_100g
#   - nutriments.proteins_100g
#   - nutriments.salt_100g
#   - nutriments.saturated-fat_100g
#   - nutriments.sodium_100g
#   - nutriments.sugars_100g
#   - ecoscore_score
#   - nutriments.magnesium_100g
#   - nutriments.vitamin-b6_100g
#   - nutriments.vitamin-e_100g
#   - nutriments.vitamin-b12_100g
#   - nutriments.calcium_100g
#   - nutriments.potassium_100g
#   - nutriments.copper_100g
#   - nutriments.iron_100g
#   - nutriments.zinc_100g
#   - nutriments.biotin_100g
#   - nutriments.vitamin-c_100g
#   - nutriments.vitamin-d_100g
#   - nutriments.phosphorus_100g
#   - nutriments.pantothenic-acid_100g
#   - nutriments.trans-fat_100g
#   - nutriments.cholesterol_100g
#   - nutriments.vitamin-a_100g
#   - nutriments.manganese_100g
#   - nutriments.selenium_100g
#   - nutriments.vitamin-k_100g

# %%
# Function to sanitize and export DataFrame to Excel
def sanitize_and_export_to_excel(df, filename="openfoodfacts_cleaned.xlsx"):
    if df.empty:
        print("DataFrame is empty. Nothing to export.")
        return
    
    try:
        # Sanitize DataFrame by removing problematic characters
        df_cleaned = df.applymap(
            lambda x: ''.join(ch for ch in str(x) if ch.isprintable()) if isinstance(x, str) else x
        )
        
        # Export cleaned DataFrame to Excel
        df_cleaned.to_excel(filename, index=False, engine="openpyxl")
        print(f"Data successfully exported to '{filename}'.")
    except Exception as e:
        print(f"Failed to export data: {e}")

# Sanitize and export the DataFrame
sanitize_and_export_to_excel(df, filename="openfoodfacts_cleaned.xlsx")
# Out:
# C:\Users\Hassan\AppData\Local\Temp\ipykernel_49348\1146107928.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cleaned = df.applymap(
# Data successfully exported to 'openfoodfacts_cleaned.xlsx'.
